# %% [markdown]
# **importing PANDAS and test the student performance dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('dataset\StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# now we will check the average scores

# %%
df['Exam_Score'].mean()
# Out:
# np.float64(67.23565914938702)

# %% [markdown]
# **we will split each case and see its mean to check the reason affecting student performance**

# %%
df.groupby(['Distance_from_Home'])['Exam_Score'].mean()
# Out:
# Distance_from_Home
# Far         66.457447
# Moderate    66.981481
# Near        67.512101
# Name: Exam_Score, dtype: float64

# %%
df.groupby('Teacher_Quality')['Exam_Score'].mean()
# Out:
# Teacher_Quality
# High      67.676939
# Low       66.753425
# Medium    67.109299
# Name: Exam_Score, dtype: float64

# %%
df.groupby('School_Type')['Exam_Score'].mean()
# Out:
# School_Type
# Private    67.287705
# Public     67.212919
# Name: Exam_Score, dtype: float64

# %%
df.groupby('Internet_Access')['Exam_Score'].mean()
# Out:
# Internet_Access
# No     66.535070
# Yes    67.292895
# Name: Exam_Score, dtype: float64

# %%
df.groupby('Hours_Studied')['Exam_Score'].mean()
# Out:
# Hours_Studied
# 1     71.000000
# 2     63.000000
# 3     61.333333
# 4     61.647059
# 5     62.857143
# 6     63.470588
# 7     64.352941
# 8     64.155172
# 9     64.162791
# 10    64.393617
# 11    64.979452
# 12    64.765625
# 13    64.724771
# 14    65.576208
# 15    65.590476
# 16    66.182336
# 17    66.328084
# 18    67.042394
# 19    66.959184
# 20    66.950538
# 21    67.682135
# 22    67.480100
# 23    68.180049
# 24    68.187675
# 25    68.847751
# 26    68.665399
# 27    69.462882
# 28    69.608187
# 29    70.283582
# 30    70.617886
# 31    70.688312
# 32    70.944444
# 33    70.025000
# 34    70.724138
# 35    71.800000
# 36    71.181818
# 37    73.333333
# 38    72.714286
# 39    74.714286
# 43    78.000000
# 44    71.000000
# Name: Exam_Score, dtype: float64

# %%
df.groupby('Attendance')['Exam_Score'].mean()
# Out:
# Attendance
# 60     62.413793
# 61     63.384146
# 62     63.756579
# 63     64.361290
# 64     63.884615
# 65     63.905063
# 66     64.537931
# 67     64.626316
# 68     65.147059
# 69     65.123529
# 70     65.527950
# 71     65.611111
# 72     65.694611
# 73     65.952381
# 74     66.272727
# 75     66.288591
# 76     66.886486
# 77     66.668478
# 78     66.890909
# 79     66.828571
# 80     67.088757
# 81     67.232143
# 82     67.341040
# 83     67.968153
# 84     67.742857
# 85     67.883562
# 86     68.655629
# 87     68.741722
# 88     68.909677
# 89     69.104938
# 90     70.012821
# 91     69.417143
# 92     69.727273
# 93     69.820359
# 94     69.588889
# 95     70.067485
# 96     70.571429
# 97     70.378882
# 98     70.684492
# 99     70.889610
# 100    70.765432
# Name: Exam_Score, dtype: float64

# %% [markdown]
# as we see in upper cells, all cases wasnt a real issue in the grades

# %% [markdown]
# let us try seeing the best  and worst learning related cases and how would be the average scores

# %%
Best_case=df[(df['Attendance']>80) & (df['Hours_Studied'] >20) & (df['Access_to_Resources']=='High') & (df['Teacher_Quality']=="High")]
Best_case['Exam_Score'].mean()
# Out:
# np.float64(71.75)

# %%
Best_case['Exam_Score'].hist()
# Out:
# <Axes: >

# %%
worst_case=df[(df['Attendance']<75) & (df['Hours_Studied'] <20) & (df['Access_to_Resources']=='Low') & (df['Teacher_Quality']=="Low")]
worst_case['Exam_Score'].mean()
# Out:
# np.float64(61.77777777777778)

# %%
worst_case['Exam_Score'].hist()
# Out:
# <Axes: >

# %% [markdown]
# i will add extra class for weak students

# %% [markdown]
# we will check if there is students got more than 100 or less than 0 and turn it to null

# %%
df[(df['Exam_Score']>100) | (df['Exam_Score']<0)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1525             27          98                  Low              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1525                        Yes            6               93
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 1525              Low              No                  5          High
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 1525            High      Public       Positive                  3
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 1525                    No              High School           Moderate
#
#       Gender  Exam_Score
# 1525  Female         101

# %%
df.loc[df['Exam_Score']>100,'Exam_Score']=None

# %%
df.loc[1525]
# Out:
# Hours_Studied                          27
# Attendance                             98
# Parental_Involvement                  Low
# Access_to_Resources                Medium
# Extracurricular_Activities            Yes
# Sleep_Hours                             6
# Previous_Scores                        93
# Motivation_Level                      Low
# Internet_Access                        No
# Tutoring_Sessions                       5
# Family_Income                        High
# Teacher_Quality                      High
# School_Type                        Public
# Peer_Influence                   Positive
# Physical_Activity                       3
# Learning_Disabilities                  No
# Parental_Education_Level      High School
# Distance_from_Home               Moderate
# Gender                             Female
# Exam_Score                            NaN
# Name: 1525, dtype: object

# %% [markdown]
# we found a student that have a "واسطة" so we set it to a null temporary

# %% [markdown]
# now we will try to add extra classes for the weak students

# %%
df['Extra_Class']=np.where(df['Exam_Score']<70,'Yes',"No")
df['Extra_Class']
# Out:
# 0       Yes
# 1       Yes
# 2        No
# 3        No
# 4        No
#        ...
# 6602    Yes
# 6603    Yes
# 6604    Yes
# 6605    Yes
# 6606    Yes
# Name: Extra_Class, Length: 6607, dtype: object

# %%
df.loc[df['Exam_Score']<70,['Exam_Score','Extra_Class']] , df.loc[df['Exam_Score']>70,['Exam_Score','Extra_Class']]
# Out:
# (      Exam_Score Extra_Class
#  0           67.0         Yes
#  1           61.0         Yes
#  6           67.0         Yes
#  7           66.0         Yes
#  8           69.0         Yes
#  ...          ...         ...
#  6602        68.0         Yes
#  6603        69.0         Yes
#  6604        68.0         Yes
#  6605        68.0         Yes
#  6606        64.0         Yes
#
#  [4982 rows x 2 columns],
#        Exam_Score Extra_Class
#  2           74.0          No
#  3           71.0          No
#  5           71.0          No
#  9           72.0          No
#  11          71.0          No
#  ...          ...         ...
#  6565        73.0          No
#  6566        76.0          No
#  6572        73.0          No
#  6592        72.0          No
#  6595        71.0          No
#
#  [1082 rows x 2 columns])

# %%
df["Extra_Class"].hist()
# Out:
# <Axes: >
